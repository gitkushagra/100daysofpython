# %% [markdown]
# <a href="https://colab.research.google.com/github/gitkushagra/100daysofpython/blob/main/(Day7)HangMan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Checking user's selection 
#Step 1 
import random
word_list = ["aardvark", "baboon", "camel"]

#TODO-1 - Randomly choose a word from the word_list and assign it to a variable called chosen_word.
num = random.randint(0,2)
chosen_word = word_list[num]

#TODO-2 - Ask the user to guess a letter and assign their answer to a variable called guess. Make guess lowercase.
guess = input("Choose a letter: ").lower()

#TODO-3 - Check if the letter the user guessed (guess) is one of the letters in the chosen_word.
for i in range(len(chosen_word)):
  if guess == chosen_word[i]:
    print('Ye! Present')
# Out:
# Choose a letter: l
# Ye! Present

# %%
# make a list with dashes and replace the correct position of guessed letter 
#Step 2

import random
word_list = ["aardvark", "baboon", "camel"]
chosen_word = random.choice(word_list)

#Testing code
print(f'Pssst, the solution is {chosen_word}.')

#TODO-1: - Create an empty List called display.
#For each letter in the chosen_word, add a "_" to 'display'.
#So if the chosen_word was "apple", display should be ["_", "_", "_", "_", "_"] with 5 "_" representing each letter to guess.

guess = input("Guess a letter: ").lower()
arr = []
for i in range(len(chosen_word)):
  arr.append("_")
#TODO-2: - Loop through each position in the chosen_word;
#If the letter at that position matches 'guess' then reveal that letter in the display at that position.
#e.g. If the user guessed "p" and the chosen word was "apple", then display should be ["_", "p", "p", "_", "_"].
for i in range(len(chosen_word)):
  if chosen_word[i] == guess:
    arr[i] = guess
print(arr)


#TODO-3: - Print 'display' and you should see the guessed letter in the correct position and every other letter replace with "_".
#Hint - Don't worry about getting the user to guess the next letter. We'll tackle that in step 3.0
# Out:
# Pssst, the solution is camel.
# Guess a letter: a
# ['_', 'a', '_', '_', '_']

# %%
#Important
word_list = ["aardvark", "baboon", "camel"]
if "baboon" in word_list:
    print("yay!")
word = "Welcome"
print(word.split())
# Out:
# yay!
# ['Welcome']

# %%
#Step 3

import random
word_list = ["aardvark", "baboon", "camel"]
chosen_word = random.choice(word_list)
word_length = len(chosen_word)

#Testing code
print(f'Pssst, the solution is {chosen_word}.')

#Create blanks
display = []
for _ in range(word_length):
    display += "_"

#TODO-1: - Use a while loop to let the user guess again. The loop should only stop once the user has guessed all the letters in the chosen_word and 'display' has no more blanks ("_"). Then you can tell the user they've won.
condition = False
while not condition:
  guess = input("Guess a letter: ").lower()
  #Check guessed letter
  for position in range(word_length):
    letter = chosen_word[position]
    print(f"Current position: {position}\n Current letter: {letter}\n Guessed letter: {guess}")
    if letter == guess:
        display[position] = letter

   
    if "_" not in display:
        condition = True
print(display)
print("You Win!")
# Out:
# Pssst, the solution is aardvark.
# Guess a letter: a
# Current position: 0
#  Current letter: a
#  Guessed letter: a
# Current position: 1
#  Current letter: a
#  Guessed letter: a
# Current position: 2
#  Current letter: r
#  Guessed letter: a
# Current position: 3
#  Current letter: d
#  Guessed letter: a
# Current position: 4
#  Current letter: v
#  Guessed letter: a
# Current position: 5
#  Current letter: a
#  Guessed letter: a
# Current position: 6
#  Current letter: r
#  Guessed letter: a
# Current position: 7
#  Current letter: k
#  Guessed letter: a
# Guess a letter: r
# Current position: 0
#  Current letter: a
#  Guessed letter: r
# Current position: 1
#  Current letter: a
#  Guessed letter: r
# Current position: 2
#  Current letter: r
#  Guessed letter: r
# Current position: 3
#  Current letter: d
#  Guessed letter: r
# Current position: 4
#  Current letter: v
#  Guessed letter: r
# Current position: 5
#  Current letter: a
#  Guessed letter: r
# Current position: 6
#  Current letter: r
#  Guessed letter: r
# Current position: 7
#  Current letter: k
#  Guessed letter: r
# Guess a letter: v
# Current position: 0
#  Current letter: a
#  Guessed letter: v
# Current position: 1
#  Current letter: a
#  Guessed letter: v
# Current position: 2
#  Current letter: r
#  Guessed letter: v
# Current position: 3
#  Current letter: d
#  Guessed letter: v
# Current position: 4
#  Current letter: v
#  Guessed letter: v
# Current position: 5
#  Current letter: a
#  Guessed letter: v
# Current position: 6
#  Current letter: r
#  Guessed letter: v
# Current position: 7
#  Current letter: k
#  Guessed letter: v
# Guess a letter: d
# Current position: 0
#  Current letter: a
#  Guessed letter: d
# Current position: 1
#  Current letter: a
#  Guessed letter: d
# Current position: 2
#  Current letter: r
#  Guessed letter: d
# Current position: 3
#  Current letter: d
#  Guessed letter: d
# Current position: 4
#  Current letter: v
#  Guessed letter: d
# Current position: 5
#  Current letter: a
#  Guessed letter: d
# Current position: 6
#  Current letter: r
#  Guessed letter: d
# Current position: 7
#  Current letter: k
#  Guessed letter: d
# Guess a letter: r
# Current position: 0
#  Current letter: a
#  Guessed letter: r
# Current position: 1
#  Current letter: a
#  Guessed letter: r
# Current position: 2
#  Current letter: r
#  Guessed letter: r
# Current position: 3
#  Current letter: d
#  Guessed letter: r
# Current position: 4
#  Current letter: v
#  Guessed letter: r
# Current position: 5
#  Current letter: a
#  Guessed letter: r
# Current position: 6
#  Current letter: r
#  Guessed letter: r
# Current position: 7
#  Current letter: k
#  Guessed letter: r
# Guess a letter: k
# Current position: 0
#  Current letter: a
#  Guessed letter: k
# Current position: 1
#  Current letter: a
#  Guessed letter: k
# Current position: 2
#  Current letter: r
#  Guessed letter: k
# Current position: 3
#  Current letter: d
#  Guessed letter: k
# Current position: 4
#  Current letter: v
#  Guessed letter: k
# Current position: 5
#  Current letter: a
#  Guessed letter: k
# Current position: 6
#  Current letter: r
#  Guessed letter: k
# Current position: 7
#  Current letter: k
#  Guessed letter: k
# ['a', 'a', 'r', 'd', 'v', 'a', 'r', 'k']
# You Win!

# %%
#Step 4
import random

stages = ['''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========
''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========
''', '''
  +---+
  |   |
      |
      |
      |
      |
=========
''']

end_of_game = False
word_list = ["ardvark", "baboon", "camel"]
chosen_word = random.choice(word_list)
word_length = len(chosen_word)

#TODO-1: - Create a variable called 'lives' to keep track of the number of lives left. 
#Set 'lives' to equal 6.
lives = 6
#Testing code
print(f'Pssst, the solution is {chosen_word}.')

#Create blanks
display = []
for _ in range(word_length):
    display += "_"

while not end_of_game:
    guess = input("Guess a letter: ").lower()
    
    #Check guessed letter
    for position in range(word_length):
        letter = chosen_word[position]
        # print(f"Current position: {position}\n Current letter: {letter}\n Guessed letter: {guess}")
        if letter == guess:
            display[position] = letter

    #TODO-2: - If guess is not a letter in the chosen_word,
    #Then reduce 'lives' by 1. 
    #If lives goes down to 0 then the game should stop and it should print "You lose."
    if guess not in chosen_word:
      lives -= 1
      print("Lives left: "+str(lives))
      if lives <= 0:
         print("You lose!")
         end_of_game = True
    #Join all the elements in the list and turn it into a String.
    print(f"{' '.join(display)}")

    #Check if user has got all letters.
    if "_" not in display:
        end_of_game = True
        print("You win.")

    #TODO-3: - print the ASCII art from 'stages' that corresponds to the current number of 'lives' the user has remaining.
    print(stages[lives])
# Out:
# Pssst, the solution is ardvark.
# Guess a letter: c
# Lives left: 5
# _ _ _ _ _ _ _
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Guess a letter: a
# a _ _ _ a _ _
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Guess a letter: m
# Lives left: 4
# a _ _ _ a _ _
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
#
# Guess a letter: r
# a r _ _ a r _
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
#
# Guess a letter: cv
# Lives left: 3
# a r _ _ a r _
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========
# Guess a letter: k
# a r _ _ a r k
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========
# Guess a letter: m
# Lives left: 2
# a r _ _ a r k
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# =========
#
# Guess a letter: p
# Lives left: 1
# a r _ _ a r k
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# =========
#
# Guess a letter: a
# a r _ _ a r k
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# =========
#
# Guess a letter: t
# Lives left: 0
# You lose!
# a r _ _ a r k
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  / \  |
#       |
# =========

# %%
#Step 5
# FINAL PROJECT
import random

#TODO-1: - Update the word list to use the 'word_list' from hangman_words.py
#Delete this line: word_list = ["ardvark", "baboon", "camel"]
import hangman_words
import hangman_art
chosen_word = random.choice(hangman_words.word_list)
word_length = len(chosen_word)

end_of_game = False
lives = 6

#TODO-3: - Import the logo from hangman_art.py and print it at the start of the game.
print(hangman_art.logo)
#Testing code
#print(f'Pssst, the solution is {chosen_word}.')

#Create blanks
display = []
for _ in range(word_length):
    display += "_"

while not end_of_game:
    guess = input("Guess a letter: ").lower()

    #TODO-4: - If the user has entered a letter they've already guessed, print the letter and let them know.

    #Check guessed letter
    for position in range(word_length):
        letter = chosen_word[position]
        #print(f"Current position: {position}\n Current letter: {letter}\n Guessed letter: {guess}")
        if letter == guess:
            display[position] = letter

    #Check if user is wrong.
    if guess not in chosen_word:
        #TODO-5: - If the letter is not in the chosen_word, print out the letter and let them know it's not in the word.
        lives -= 1
        if lives == 0:
            end_of_game = True
            print("You lose.")

    #Join all the elements in the list and turn it into a String.
    print(f"{' '.join(display)}")

    #Check if user has got all letters.
    if "_" not in display:
        end_of_game = True
        print("You win.")

    #TODO-2: - Import the stages from hangman_art.py and make this error go away.
    print(hangman_art.stages[lives])
# Out:
#
#  _
# | |
# | |__   __ _ _ __   __ _ _ __ ___   __ _ _ __
# | '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \
# | | | | (_| | | | | (_| | | | | | | (_| | | | |
# |_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
#                     __/ |
#                    |___/
# Guess a letter: a
# _ _ _ _ a _ _ _ _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
#
# Guess a letter: m
# _ _ _ _ a _ _ _ _ _
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# Guess a letter: q
# _ _ _ _ a _ _ _ _ _
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
#
# Guess a letter: w
# _ _ _ _ a _ _ _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========
# Guess a letter: s
# _ _ _ _ a _ _ _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# =========
#
# Guess a letter: p
# _ _ _ _ a _ _ _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# =========
#
# Guess a letter: k
# You lose.
# _ _ _ _ a _ _ _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  / \  |
#       |
# =========
